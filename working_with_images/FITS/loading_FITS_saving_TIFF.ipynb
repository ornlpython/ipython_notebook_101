# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# to get the new viridis colorbar, I had to make sure I had the 1.5 version of matplotlib
# > conda install matplotlib
#
# NB:
# > pip install --upgrade matplotlib
#
# install matplotlib with success, but the pyplot module of matplotlib had an error and could not be used.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '1.5.0'

# %%
image_file = 'data/data.fits'

# %%
import os

# %%
print(os.path.isfile(image_file))
# Out:
# True

# %%
# pip install pyfits
import pyfits

# %%
hdu_list = pyfits.open(image_file)

# %%
print(hdu_list)
# Out:
# [<pyfits.hdu.image.PrimaryHDU object at 0x10ae76ac8>]

# %%
# get viridis colormap

# %% [markdown]
# ### Rotate (using numpy)

# %%
rotated_data = np.rot90((np.rot90(np.rot90(hdu.data))))

# %%
hdu = hdu_list[0]
plt.figure(figsize=(10,10))
plt.imshow(rotated_data, cmap='viridis')
plt.colorbar()

# %%
type(hdu.data)
# Out:
# numpy.ndarray

# %%
from PIL import Image
import numpy as np

# %%
output_image_file = 'data/data.tif'

# %%
new_image = Image.fromarray(np.float32(hdu.data))  #essential to be a 32bits to keep the right format of data

# %%
type(new_image)
# Out:
# PIL.Image.Image

# %%
new_image.save(output_image_file)
